# %%
import os
import time
import math
import torch
import seaborn as sns

import numpy as np
import pandas as pd
import scipy as sp
import anndata as ad
from utils.train_util import Siamese_Trainer
from utils.data_util import dataset, test_data
import matplotlib.pyplot as plt

from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
os.environ["CUDA_LAUNCH_BLOCKING"] = '1'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %% [markdown]
# ### uni variant  data as input

# %%
dat = dataset(mod1='data/PBMC_10X_GEX.training.h5ad', 
              mod2='data/PBMC_10X_ATAC.training.h5ad',
              batch_number=250, C=2.0, validation=True)
# Out:
# Loading mod1 from data/PBMC_10X_GEX.training.h5ad
# Loading mod2 from data/PBMC_10X_ATAC.training.h5ad
# mod1:  (10412, 36601)
# mod2:  (10412, 18652)
# Selecting and ordering features...
# /mnt/hdd/chaozhong/pylib/site-packages/scanpy/preprocessing/_simple.py:845: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# Normalizing data to range between 0 and 1...
# 19 labels detected.
# Spliting each batch into training and validation...
# Training dataset:
# 	8330 cells,
#
# Validation dataset:
# 	2082 cells,

# %%
train = Siamese_Trainer(dat, num_epochs=100, batch_number=250, model_path='./ckpts/',
                        num_peaks=6245, num_genes=6245, margin = 2.5,
                        lamb=1.0, lr=1e-4, validation=True)

# %%
log_file = 'ckpts/SiaAtt_margin2.5_lamb_1.0.txt'
with open(log_file, 'w') as fw:
    #fw.write(str(args)+'\n')
    train.train(fw, intervals=1, initial=True)
# Out:
# /mnt/hdd/chaozhong/manuscript/fig5/train/utils/train_util.py:40: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(p)
# /mnt/hdd/chaozhong/manuscript/fig5/train/utils/train_util.py:42: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   nn.init.normal(p, 0, 1)
# Generating siamese pairs...
# After epoch 1 Train Accuracy: 0.548, Train Loss: 15.355
# After epoch 1 Val Accuracy: 0.554, Val Loss: 14.621
# Generating siamese pairs...
# After epoch 2 Train Accuracy: 0.802, Train Loss: 6.003
# After epoch 2 Val Accuracy: 0.731, Val Loss: 7.848
# Generating siamese pairs...
# After epoch 3 Train Accuracy: 0.894, Train Loss: 3.887
# After epoch 3 Val Accuracy: 0.783, Val Loss: 6.281
# Generating siamese pairs...
# After epoch 4 Train Accuracy: 0.946, Train Loss: 2.833
# After epoch 4 Val Accuracy: 0.808, Val Loss: 5.407
# Generating siamese pairs...
# ...
